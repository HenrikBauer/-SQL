# %% [markdown]
# ! Verbindungstest mit SQL Server

# %%
#r "nuget:Microsoft.DotNet.Interactive.SqlServer, *-*"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.DotNet.Interactive.SqlServer, 1.0.0-beta.25323.1</span></li></ul></div></div>
# Loading extension script from `/home/vscode/.nuget/packages/microsoft.dotnet.interactive.sqlserver/1.0.0-beta.25323.1/interactive-extensions/dotnet/extension.dib`
# <details><summary>Query Microsoft SQL Server databases.</summary>
# <p>This extension adds support for connecting to Microsoft SQL Server databases using the <code>#!connect mssql</code> magic command. For more information, run a cell using the <code>#!sql</code> magic command.</p>
# </details>

# %%
#!connect mssql --kernel-name SQL --connection-string "Server=localhost;Database=master;User Id=sa;Password=P@ssw0rd;TrustServerCertificate=true;"
# Out:
# Kernel added: #!sql-SQL

# %%
SELECT GETDATE() AS CurrentDateTime, SYSTEM_USER AS CurrentUser, DB_NAME() AS CurrentDatabase, @@SERVERNAME AS ServerName, @@VERSION AS SQLServerVersion;
# Out:
# (1 row affected)
# <table><thead><tr><td><span>CurrentDateTime</span></td><td><span>CurrentUser</span></td><td><span>CurrentDatabase</span></td><td><span>ServerName</span></td><td><span>SQLServerVersion</span></td></tr></thead><tbody><tr><td><span>2026-01-02 21:21:18Z</span></td><td>sa</td><td>master</td><td>461040f39116</td><td>Microsoft SQL Server 2025 (RTM) - 17.0.1000.7 (X64)
# 	Oct 21 2025 12:05:57
# 	Copyright (C) 2025 Microsoft Corporation
# 	Enterprise Developer Edition (64-bit) on Linux (Ubuntu 22.04.5 LTS) &lt;X64&gt;</td></tr></tbody></table><style>
# .dni-code-hint {
#     font-style: italic;
#     overflow: hidden;
#     white-space: nowrap;
# }
# .dni-treeview {
#     white-space: nowrap;
# }
# .dni-treeview td {
#     vertical-align: top;
#     text-align: start;
# }
# details.dni-treeview {
#     padding-left: 1em;
# }
# table td {
#     text-align: start;
# }
# table tr {
#     vertical-align: top;
#     margin: 0em 0px;
# }
# table tr td pre
# {
# ...
